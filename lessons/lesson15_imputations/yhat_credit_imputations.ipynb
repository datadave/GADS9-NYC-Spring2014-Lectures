# %% [markdown]
# #Handling Missing Data
#
# _This notebook comes from a series done by yhat from DataGotham2013. You can view all the notebooks [here](http://nbviewer.ipython.org/github/yhat/DataGotham2013/tree/master/notebooks/)._

# %% [markdown]
# #In this workbook you will
# - Learn about imputation and what it's used for
# - Use the KNearestNeighbors algorithm to impute data
# - Come up with your own imputation strategy

# %% [markdown]
# #Imputation
# Imputation is fairly intuitive. For the missing data in our dataset, we're going to replace it with values that come from similar records in our dataset that aren't null.
# To do this we're going to use the NearestNeighbors algorithm.

# %%
import pandas as pd
import numpy as np
import pylab as pl

# %%
df = pd.read_csv("./data/credit-data-post-import.csv")

# %% [markdown]
# ##Cross Validation
# We're going to use the simplest type of cross validation. we'll simply split our data into 2 groups: training and test. we'll use the training set to calibrate our model and then use the test set to  evaluate how effective it is.

# %%
is_test = np.random.uniform(0, 1, len(df)) > 0.75
train = df[is_test==False]
test = df[is_test==True]

# %%
len(train), len(test)
# Out:
# (112843, 37157)

# %% [markdown]
# ##Be sure to calibrate the imputation with the training set

# %%
from sklearn.neighbors import KNeighborsRegressor

income_imputer = KNeighborsRegressor(n_neighbors=1)

#split our data into 2 groups; data containing nulls and data 
# not containing nulls we'll train on the latter and make
# 'predictions' on the null data to impute monthly_income
train_w_monthly_income = train[train.monthly_income.isnull()==False]
train_w_null_monthly_income = train[train.monthly_income.isnull()==True]

# %%
a.interpolate()
# Out:
#                                              serious_dlqin2yrs  \
# serious_dlqin2yrs                                     1.000000
# revolving_utilization_of_unsecured_lines             -0.001976
# age                                                  -0.100847
# number_of_time30-59_days_past_due_not_worse           0.126213
# debt_ratio                                           -0.006619
# monthly_income                                       -0.018097
# number_of_open_credit_lines_and_loans                -0.024777
# number_of_times90_days_late                           0.113098
# number_real_estate_loans_or_lines                    -0.001436
# number_of_time60-89_days_past_due_not_worse           0.095959
# number_of_dependents                                  0.047099
#
#                                              revolving_utilization_of_unsecured_lines  \
# serious_dlqin2yrs                                                           -0.001976
# revolving_utilization_of_unsecured_lines                                     1.000000
# age                                                                         -0.004029
# number_of_time30-59_days_past_due_not_worse                                 -0.001209
# debt_ratio                                                                  -0.001174
# monthly_income                                                               0.007907
# number_of_open_credit_lines_and_loans                                       -0.010240
# number_of_times90_days_late                                                 -0.000807
# number_real_estate_loans_or_lines                                            0.006517
# number_of_time60-89_days_past_due_not_worse                                 -0.000905
# number_of_dependents                                                         0.001951
#
#                                                   age  \
# serious_dlqin2yrs                           -0.100847
# revolving_utilization_of_unsecured_lines    -0.004029
# age                                          1.000000
# number_of_time30-59_days_past_due_not_worse -0.048973
# debt_ratio                                   0.000006
# monthly_income                               0.035504
# number_of_open_credit_lines_and_loans        0.186668
# number_of_times90_days_late                 -0.047626
# number_real_estate_loans_or_lines            0.063633
# number_of_time60-89_days_past_due_not_worse -0.043189
# number_of_dependents                        -0.204934
#
#                                              number_of_time30-59_days_past_due_not_worse  \
# serious_dlqin2yrs                                                               0.126213
# revolving_utilization_of_unsecured_lines                                       -0.001209
# age                                                                            -0.048973
# number_of_time30-59_days_past_due_not_worse                                     1.000000
# debt_ratio                                                                     -0.001718
# monthly_income                                                                 -0.009921
# number_of_open_credit_lines_and_loans                                          -0.042346
# number_of_times90_days_late                                                     0.974562
# number_real_estate_loans_or_lines                                              -0.023431
# number_of_time60-89_days_past_due_not_worse                                     0.979520
# number_of_dependents                                                            0.001935
#
#                                              debt_ratio  monthly_income  \
# serious_dlqin2yrs                             -0.006619       -0.018097
# revolving_utilization_of_unsecured_lines      -0.001174        0.007907
# age                                            0.000006        0.035504
# number_of_time30-59_days_past_due_not_worse   -0.001718       -0.009921
# debt_ratio                                     1.000000       -0.025796
# monthly_income                                -0.025796        1.000000
# number_of_open_credit_lines_and_loans          0.007992        0.084560
# number_of_times90_days_late                   -0.002899       -0.011576
# number_real_estate_loans_or_lines              0.017001        0.118023
# number_of_time60-89_days_past_due_not_worse   -0.001599       -0.010187
# number_of_dependents                           0.007262        0.059868
#
#                                              number_of_open_credit_lines_and_loans  \
# serious_dlqin2yrs                                                        -0.024777
# revolving_utilization_of_unsecured_lines                                 -0.010240
# age                                                                       0.186668
# number_of_time30-59_days_past_due_not_worse                              -0.042346
# debt_ratio                                                                0.007992
# monthly_income                                                            0.084560
# number_of_open_credit_lines_and_loans                                     1.000000
# number_of_times90_days_late                                              -0.071345
# number_real_estate_loans_or_lines                                         0.425577
# number_of_time60-89_days_past_due_not_worse                              -0.060679
# number_of_dependents                                                      0.037281
#
#                                              number_of_times90_days_late  \
# serious_dlqin2yrs                                               0.113098
# revolving_utilization_of_unsecured_lines                       -0.000807
# age                                                            -0.047626
# number_of_time30-59_days_past_due_not_worse                     0.974562
# debt_ratio                                                     -0.002899
# monthly_income                                                 -0.011576
# number_of_open_credit_lines_and_loans                          -0.071345
# number_of_times90_days_late                                     1.000000
# number_real_estate_loans_or_lines                              -0.040223
# number_of_time60-89_days_past_due_not_worse                     0.988966
# number_of_dependents                                           -0.005821
#
#                                              number_real_estate_loans_or_lines  \
# serious_dlqin2yrs                                                    -0.001436
# revolving_utilization_of_unsecured_lines                              0.006517
# age                                                                   0.063633
# number_of_time30-59_days_past_due_not_worse                          -0.023431
# debt_ratio                                                            0.017001
# monthly_income                                                        0.118023
# number_of_open_credit_lines_and_loans                                 0.425577
# number_of_times90_days_late                                          -0.040223
# number_real_estate_loans_or_lines                                     1.000000
# number_of_time60-89_days_past_due_not_worse                          -0.033897
# number_of_dependents                                                  0.120261
#
#                                              number_of_time60-89_days_past_due_not_worse  \
# serious_dlqin2yrs                                                               0.095959
# revolving_utilization_of_unsecured_lines                                       -0.000905
# age                                                                            -0.043189
# number_of_time30-59_days_past_due_not_worse                                     0.979520
# debt_ratio                                                                     -0.001599
# monthly_income                                                                 -0.010187
# number_of_open_credit_lines_and_loans                                          -0.060679
# number_of_times90_days_late                                                     0.988966
# number_real_estate_loans_or_lines                                              -0.033897
# number_of_time60-89_days_past_due_not_worse                                     1.000000
# number_of_dependents                                                           -0.007316
#
#                                              number_of_dependents
# serious_dlqin2yrs                                        0.047099
# revolving_utilization_of_unsecured_lines                 0.001951
# age                                                     -0.204934
# number_of_time30-59_days_past_due_not_worse              0.001935
# debt_ratio                                               0.007262
# monthly_income                                           0.059868
# number_of_open_credit_lines_and_loans                    0.037281
# number_of_times90_days_late                             -0.005821
# number_real_estate_loans_or_lines                        0.120261
# number_of_time60-89_days_past_due_not_worse             -0.007316
# number_of_dependents                                     1.000000
#
# [11 rows x 11 columns]

# %%
a=train_w_monthly_income.corr()

# %%
plot correlatico

# %%
train_w_monthly_income
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 550
#     serious_dlqin2yrs  revolving_utilization_of_unsecured_lines  age  \
# 0                   1                                  0.766127   45
# 1                   0                                  0.957151   40
# 2                   0                                  0.658180   38
# 3                   0                                  0.233810   30
# 4                   0                                  0.907239   49
# 5                   0                                  0.213179   74
# 7                   0                                  0.754464   39
# 9                   0                                  0.189169   57
# 10                  0                                  0.644226   30
# 12                  0                                  0.010352   46
# 13                  1                                  0.964673   40
# 14                  0                                  0.019657   76
# 15                  0                                  0.548458   64
# 17                  0                                  0.166284   53
# 18                  0                                  0.221813   43
# 19                  0                                  0.602794   25
# 20                  0                                  0.200923   43
# 22                  0                                  1.000000   39
# 23                  0                                  0.075427   32
# 24                  0                                  0.046560   58
# 25                  1                                  0.392248   50
# 26                  0                                  0.052436   58
# 27                  0                                  0.034421   69
# 28                  0                                  0.452516   24
# 29                  0                                  0.392995   58
# 30                  0                                  0.704074   28
# 31                  0                                  1.000000   24
# 33                  0                                  0.186869   57
# 34                  0                                  0.693330   42
# 35                  0                                  0.000000   64
# 37                  0                                  1.000000   75
# 40                  0                                  0.719985   41
# 43                  0                                  0.718705   28
# 44                  0                                  0.368876   68
# 45                  0                                  0.000603   70
# 46                  0                                  0.061440   62
# 47                  0                                  0.140111   31
# 48                  0                                  0.834048   38
# 51                  1                                  0.728150   31
# 53                  0                                  0.028562   51
# 54                  0                                  0.992016   29
# 59                  0                                  0.655570   35
# 60                  0                                  0.651603   58
# 64                  0                                  0.337521   60
# 65                  0                                  0.000000   67
# 67                  0                                  0.006799   27
# 68                  0                                  0.004264   31
# 69                  0                                  0.269484   64
# 70                  0                                  0.265898   36
# 72                  0                                  0.827708   56
# 73                  0                                  0.059669   31
# 74                  1                                  0.133063   49
# 75                  0                                  0.234218   36
# 77                  0                                  0.460376   37
# 78                  0                                  0.335559   69
# 80                  0                                  0.183317   52
# 81                  0                                  0.074862   66
# 83                  0                                  0.054497   56
# 84                  0                                  0.029164   31
# 85                  0                                  0.000000   58
#                   ...                                       ...  ...
#
#     number_of_time30-59_days_past_due_not_worse   debt_ratio  monthly_income  \
# 0                                             2     0.802982            9120
# 1                                             0     0.121876            2600
# 2                                             1     0.085113            3042
# 3                                             0     0.036050            3300
# 4                                             1     0.024926           63588
# 5                                             0     0.375607            3500
# 7                                             0     0.209940            3500
# 9                                             0     0.606291           23684
# 10                                            0     0.309476            2500
# 12                                            0     0.298354           12454
# 13                                            3     0.382965           13700
# 14                                            0   477.000000               0
# 15                                            0     0.209892           11362
# 17                                            0     0.188274            8800
# 18                                            0     0.527888            3280
# 19                                            0     0.065868             333
# 20                                            0     0.430046           12300
# 22                                            0     0.241104            2500
# 23                                            0     0.085512            7916
# 24                                            0     0.241622            2416
# 25                                            0     1.595253            4676
# 26                                            0     0.097672            8333
# 27                                            0     0.042383            2500
# 28                                            0     0.011761            3400
# 29                                            2     0.436103            5500
# 30                                            1     0.155201            4200
# 31                                            0     0.472703             750
# 33                                            0     0.313812            7000
# 34                                            2     0.257732            2230
# 35                                            0     0.073539           11000
# 37                                            1     0.134078            3400
# 40                                            1     0.539554            5700
# 43                                            0     0.170126            3661
# 44                                            0  1687.500000               1
# 45                                            0     0.177787           16800
# 46                                            0     0.011168            3133
# 47                                            0     0.689370            1937
# 48                                            0     0.393662           13000
# 51                                            0     0.824725            3000
# 53                                            0     0.306381            5750
# 54                                            0     0.008065            2231
# 59                                            0     0.261610            5813
# 60                                            0     0.241136            7783
# 64                                            0     0.549878            4500
# 65                                            0     0.540984            3720
# 67                                            1     0.681046             764
# 68                                            0     0.111444            2000
# 69                                            0     0.161062            9455
# 70                                            0     0.262612            8384
# 72                                            0     0.369591            6793
# 73                                            0  3162.000000               0
# 74                                            1     0.182882           10257
# 75                                            0     0.116614            8600
# 77                                            0     0.074156            4975
# 78                                            0     0.270449           15000
# 80                                            0     0.111132           10833
# 81                                            0     0.208842            4500
# 83                                            0     0.492022            4950
# 84                                            0     0.395032            3300
# 85                                            0     0.316145            4886
#                                             ...          ...             ...
#
#     number_of_open_credit_lines_and_loans  number_of_times90_days_late  \
# 0                                      13                            0
# 1                                       4                            0
# 2                                       2                            1
# 3                                       5                            0
# 4                                       7                            0
# 5                                       3                            0
# 7                                       8                            0
# 9                                       9                            0
# 10                                      5                            0
# 12                                     13                            0
# 13                                      9                            3
# 14                                      6                            0
# 15                                      7                            0
# 17                                      7                            0
# 18                                      7                            0
# 19                                      2                            0
# 20                                     10                            0
# 22                                      4                            0
# 23                                      6                            0
# 24                                      9                            0
# 25                                     14                            0
# 26                                     22                            0
# 27                                     17                            0
# 28                                      1                            0
# 29                                     15                            0
# 30                                      8                            0
# 31                                      1                            0
# 33                                      9                            0
# 34                                      7                            0
# 35                                      9                            0
# 37                                      1                            0
# 40                                     14                            0
# 43                                      4                            0
# 44                                     31                            0
# 45                                     12                            0
# 46                                      2                            0
# 47                                      4                            0
# 48                                     13                            0
# 51                                     10                            0
# 53                                      5                            0
# 54                                      1                            0
# 59                                     10                            0
# 60                                     11                            0
# 64                                     10                            0
# 65                                      2                            0
# 67                                      3                            0
# 68                                      6                            1
# 69                                     13                            0
# 70                                      6                            0
# 72                                     15                            1
# 73                                     11                            0
# 74                                      9                            0
# 75                                     19                            0
# 77                                      6                            0
# 78                                     14                            0
# 80                                     14                            0
# 81                                      3                            0
# 83                                     18                            0
# 84                                     10                            0
# 85                                      9                            0
#                                       ...                          ...
#
#     number_real_estate_loans_or_lines  \
# 0                                   6
# 1                                   0
# 2                                   0
# 3                                   0
# 4                                   1
# 5                                   1
# 7                                   0
# 9                                   4
# 10                                  0
# 12                                  2
# 13                                  1
# 14                                  1
# 15                                  1
# 17                                  0
# 18                                  1
# 19                                  0
# 20                                  2
# 22                                  0
# 23                                  0
# 24                                  1
# 25                                  3
# 26                                  1
# 27                                  0
# 28                                  0
# 29                                  1
# 30                                  0
# 31                                  0
# 33                                  2
# 34                                  0
# 35                                  1
# 37                                  1
# 40                                  1
# 43                                  0
# 44                                  1
# 45                                  1
# 46                                  0
# 47                                  2
# 48                                  2
# 51                                  2
# 53                                  1
# 54                                  0
# 59                                  0
# 60                                  1
# 64                                  2
# 65                                  1
# 67                                  0
# 68                                  0
# 69                                  1
# 70                                  2
# 72                                  1
# 73                                  2
# 74                                  2
# 75                                  0
# 77                                  0
# 78                                  2
# 80                                  2
# 81                                  1
# 83                                  2
# 84                                  1
# 85                                  1
#                                   ...
#
#     number_of_time60-89_days_past_due_not_worse  number_of_dependents
# 0                                             0                     2
# 1                                             0                     1
# 2                                             0                     0
# 3                                             0                     0
# 4                                             0                     0
# 5                                             0                     1
# 7                                             0                     0
# 9                                             0                     2
# 10                                            0                     0
# 12                                            0                     2
# 13                                            1                     2
# 14                                            0                     0
# 15                                            0                     2
# 17                                            0                     0
# 18                                            0                     2
# 19                                            0                     0
# 20                                            0                     0
# 22                                            0                     0
# 23                                            0                     0
# 24                                            0                     0
# 25                                            0                     1
# 26                                            0                     0
# 27                                            0                     1
# 28                                            0                     0
# 29                                            0                     0
# 30                                            0                     0
# 31                                            0                     0
# 33                                            0                     0
# 34                                            0                     0
# 35                                            0                     0
# 37                                            0                     1
# 40                                            0                     0
# 43                                            0                     1
# 44                                            0                     0
# 45                                            0                     2
# 46                                            0                     0
# 47                                            0                     0
# 48                                            0                     2
# 51                                            0                     1
# 53                                            0                     0
# 54                                            0                     0
# 59                                            0                     2
# 60                                            0                     0
# 64                                            0                     0
# 65                                            0                     0
# 67                                            0                     0
# 68                                            0                     2
# 69                                            0                     3
# 70                                            0                     1
# 72                                            0                     0
# 73                                            0                     1
# 74                                            0                     3
# 75                                            0                     3
# 77                                            0                     0
# 78                                            0                     1
# 80                                            0                     1
# 81                                            0                     0
# 83                                            0                     0
# 84                                            0                     0
# 85                                            0                     1
#                                             ...                   ...
#
# [90632 rows x 11 columns]

# %%
a=train_w_monthly_income.corr()
# Out:
#                                              serious_dlqin2yrs  \
# serious_dlqin2yrs                                     1.000000
# revolving_utilization_of_unsecured_lines             -0.001976
# age                                                  -0.100847
# number_of_time30-59_days_past_due_not_worse           0.126213
# debt_ratio                                           -0.006619
# monthly_income                                       -0.018097
# number_of_open_credit_lines_and_loans                -0.024777
# number_of_times90_days_late                           0.113098
# number_real_estate_loans_or_lines                    -0.001436
# number_of_time60-89_days_past_due_not_worse           0.095959
# number_of_dependents                                  0.047099
#
#                                              revolving_utilization_of_unsecured_lines  \
# serious_dlqin2yrs                                                           -0.001976
# revolving_utilization_of_unsecured_lines                                     1.000000
# age                                                                         -0.004029
# number_of_time30-59_days_past_due_not_worse                                 -0.001209
# debt_ratio                                                                  -0.001174
# monthly_income                                                               0.007907
# number_of_open_credit_lines_and_loans                                       -0.010240
# number_of_times90_days_late                                                 -0.000807
# number_real_estate_loans_or_lines                                            0.006517
# number_of_time60-89_days_past_due_not_worse                                 -0.000905
# number_of_dependents                                                         0.001951
#
#                                                   age  \
# serious_dlqin2yrs                           -0.100847
# revolving_utilization_of_unsecured_lines    -0.004029
# age                                          1.000000
# number_of_time30-59_days_past_due_not_worse -0.048973
# debt_ratio                                   0.000006
# monthly_income                               0.035504
# number_of_open_credit_lines_and_loans        0.186668
# number_of_times90_days_late                 -0.047626
# number_real_estate_loans_or_lines            0.063633
# number_of_time60-89_days_past_due_not_worse -0.043189
# number_of_dependents                        -0.204934
#
#                                              number_of_time30-59_days_past_due_not_worse  \
# serious_dlqin2yrs                                                               0.126213
# revolving_utilization_of_unsecured_lines                                       -0.001209
# age                                                                            -0.048973
# number_of_time30-59_days_past_due_not_worse                                     1.000000
# debt_ratio                                                                     -0.001718
# monthly_income                                                                 -0.009921
# number_of_open_credit_lines_and_loans                                          -0.042346
# number_of_times90_days_late                                                     0.974562
# number_real_estate_loans_or_lines                                              -0.023431
# number_of_time60-89_days_past_due_not_worse                                     0.979520
# number_of_dependents                                                            0.001935
#
#                                              debt_ratio  monthly_income  \
# serious_dlqin2yrs                             -0.006619       -0.018097
# revolving_utilization_of_unsecured_lines      -0.001174        0.007907
# age                                            0.000006        0.035504
# number_of_time30-59_days_past_due_not_worse   -0.001718       -0.009921
# debt_ratio                                     1.000000       -0.025796
# monthly_income                                -0.025796        1.000000
# number_of_open_credit_lines_and_loans          0.007992        0.084560
# number_of_times90_days_late                   -0.002899       -0.011576
# number_real_estate_loans_or_lines              0.017001        0.118023
# number_of_time60-89_days_past_due_not_worse   -0.001599       -0.010187
# number_of_dependents                           0.007262        0.059868
#
#                                              number_of_open_credit_lines_and_loans  \
# serious_dlqin2yrs                                                        -0.024777
# revolving_utilization_of_unsecured_lines                                 -0.010240
# age                                                                       0.186668
# number_of_time30-59_days_past_due_not_worse                              -0.042346
# debt_ratio                                                                0.007992
# monthly_income                                                            0.084560
# number_of_open_credit_lines_and_loans                                     1.000000
# number_of_times90_days_late                                              -0.071345
# number_real_estate_loans_or_lines                                         0.425577
# number_of_time60-89_days_past_due_not_worse                              -0.060679
# number_of_dependents                                                      0.037281
#
#                                              number_of_times90_days_late  \
# serious_dlqin2yrs                                               0.113098
# revolving_utilization_of_unsecured_lines                       -0.000807
# age                                                            -0.047626
# number_of_time30-59_days_past_due_not_worse                     0.974562
# debt_ratio                                                     -0.002899
# monthly_income                                                 -0.011576
# number_of_open_credit_lines_and_loans                          -0.071345
# number_of_times90_days_late                                     1.000000
# number_real_estate_loans_or_lines                              -0.040223
# number_of_time60-89_days_past_due_not_worse                     0.988966
# number_of_dependents                                           -0.005821
#
#                                              number_real_estate_loans_or_lines  \
# serious_dlqin2yrs                                                    -0.001436
# revolving_utilization_of_unsecured_lines                              0.006517
# age                                                                   0.063633
# number_of_time30-59_days_past_due_not_worse                          -0.023431
# debt_ratio                                                            0.017001
# monthly_income                                                        0.118023
# number_of_open_credit_lines_and_loans                                 0.425577
# number_of_times90_days_late                                          -0.040223
# number_real_estate_loans_or_lines                                     1.000000
# number_of_time60-89_days_past_due_not_worse                          -0.033897
# number_of_dependents                                                  0.120261
#
#                                              number_of_time60-89_days_past_due_not_worse  \
# serious_dlqin2yrs                                                               0.095959
# revolving_utilization_of_unsecured_lines                                       -0.000905
# age                                                                            -0.043189
# number_of_time30-59_days_past_due_not_worse                                     0.979520
# debt_ratio                                                                     -0.001599
# monthly_income                                                                 -0.010187
# number_of_open_credit_lines_and_loans                                          -0.060679
# number_of_times90_days_late                                                     0.988966
# number_real_estate_loans_or_lines                                              -0.033897
# number_of_time60-89_days_past_due_not_worse                                     1.000000
# number_of_dependents                                                           -0.007316
#
#                                              number_of_dependents
# serious_dlqin2yrs                                        0.047099
# revolving_utilization_of_unsecured_lines                 0.001951
# age                                                     -0.204934
# number_of_time30-59_days_past_due_not_worse              0.001935
# debt_ratio                                               0.007262
# monthly_income                                           0.059868
# number_of_open_credit_lines_and_loans                    0.037281
# number_of_times90_days_late                             -0.005821
# number_real_estate_loans_or_lines                        0.120261
# number_of_time60-89_days_past_due_not_worse             -0.007316
# number_of_dependents                                     1.000000
#
# [11 rows x 11 columns]

# %%
train_w_monthly_income.corr().ix[:,5]
# Out:
# serious_dlqin2yrs                             -0.018097
# revolving_utilization_of_unsecured_lines       0.007907
# age                                            0.035504
# number_of_time30-59_days_past_due_not_worse   -0.009921
# debt_ratio                                    -0.025796
# monthly_income                                 1.000000
# number_of_open_credit_lines_and_loans          0.084560
# number_of_times90_days_late                   -0.011576
# number_real_estate_loans_or_lines              0.118023
# number_of_time60-89_days_past_due_not_worse   -0.010187
# number_of_dependents                           0.059868
# Name: monthly_income, dtype: float64

# %%
cols = ['number_real_estate_loans_or_lines', 'number_of_open_credit_lines_and_loans']
income_imputer.fit(train_w_monthly_income[cols], train_w_monthly_income.monthly_income)
# Out:
# KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#           n_neighbors=1, p=2, weights='uniform')

# %% [markdown]
# ##Replace the missing values

# %%
new_values = income_imputer.predict(train_w_null_monthly_income[cols])

# %%
train_w_null_monthly_income['monthly_income'] = new_values
new_values
# Out:
# -c:1: SettingWithCopyWarning: A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_index,col_indexer] = value instead
# array([  3584.,   4250.,   6210., ...,   3717.,  10417.,   6135.])

# %%
pd.interpolate()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-41b859937ef8> in <module>()
# ----> 1 pd.interpolate()
#
# AttributeError: 'module' object has no attribute 'interpolate'

# %%
#combine the data back together
train = train_w_monthly_income.append(train_w_null_monthly_income)
len(train)
# Out:
# 112843

# %%
test['monthly_income_imputed'] = income_imputer.predict(test[cols])
test.head()
# Out:
#     serious_dlqin2yrs  revolving_utilization_of_unsecured_lines  age  \
# 6                   0                                  0.305682   57
# 11                  0                                  0.018798   51
# 21                  1                                  0.025656   38
# 36                  0                                  0.881836   50
# 38                  0                                  0.363636   26
#
#     number_of_time30-59_days_past_due_not_worse   debt_ratio  monthly_income  \
# 6                                             0  5710.000000             NaN
# 11                                            0     0.531529            6501
# 21                                            0     0.475841            3000
# 36                                            3     0.567858            4000
# 38                                            0     0.009990            1000
#
#     number_of_open_credit_lines_and_loans  number_of_times90_days_late  \
# 6                                       8                            0
# 11                                      7                            0
# 21                                      7                            0
# 36                                      9                            0
# 38                                      1                            0
#
#     number_real_estate_loans_or_lines  \
# 6                                   3
# 11                                  2
# 21                                  1
# 36                                  1
# 38                                  0
#
#     number_of_time60-89_days_past_due_not_worse  number_of_dependents  \
# 6                                             0                     0
# 11                                            0                     2
# 21                                            0                     2
# 36                                            0                     1
# 38                                            0                     0
#
#     monthly_income_imputed
# 6                     8000
# 11                    9000
# 21                    7203
# 36                    8723
# 38                    6200
#
# [5 rows x 12 columns]

# %%
test['monthly_income'] = np.where(test.monthly_income.isnull(), test.monthly_income_imputed,
                                  test.monthly_income)
# Out:
# -c:2: SettingWithCopyWarning: A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_index,col_indexer] = value instead

# %%
print pd.value_counts(train.monthly_income.isnull())
print pd.value_counts(test.monthly_income.isnull())
# Out:
# False    112843
# dtype: int64
# False    37157
# dtype: int64

# %%
train.to_csv("./data/credit-data-trainingset.csv", index=False)
test.to_csv("./data/credit-data-testset.csv", index=False)

# %% [markdown]
# ##Trying your own imputation strategy
# Partner with the person next to you and think of other ways you might be able to impute missing valus for the `monthly_income` column.
#
# Things to consider:
#
# - Are `number_of_open_credit_lines_and_loans` and `number_real_estate_loans_or_lines` the best predictors?
# - What are some other methods you could use for replacing nulls?
# - What about handling outlying values? Should a montly income of $3MM be treated as missing?
# - Check out the [scikit-learn docs](http://scikit-learn.org/stable/auto_examples/imputation.html) for more examples
# - How might you evaluate the effectiveness of your imputation?

# %% [markdown]
# ##We just did the following
#
# - Split our data into a training set for building our model and a test set for evaluating its performance
# - Used KNearestNeighbors to fill in missing values for `monthly_income`
